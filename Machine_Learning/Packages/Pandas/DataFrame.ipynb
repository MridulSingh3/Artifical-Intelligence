# %%
import pandas as pd

info={
    "Name":["Rahul","Mridul","Jay"],
    "CGPA":[9.3,9.9,7.9]
}

df=pd.DataFrame(info)
print(df)
df
# Out:
#      Name  CGPA
# 0   Rahul   9.3
# 1  Mridul   9.9
# 2     Jay   7.9
#      Name  CGPA
# 0   Rahul   9.3
# 1  Mridul   9.9
# 2     Jay   7.9

# %%
import pandas as pd

df=pd.DataFrame([["Adam",23],["Mohan",20],["Anil",25]], columns=["Name","Age"])
print(df)
# Out:
#     Name  Age
# 0   Adam   23
# 1  Mohan   20
# 2   Anil   25
