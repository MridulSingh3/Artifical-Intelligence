# %%
import pandas as pd

s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))

#index
print(s[2])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# 3

# %%
s=pd.Series([20,24,21,22], index=["Jay","Shayam Ji","Mridul","Prem"])
print(s)
print(s["Jay"])
# Out:
# Jay          20
# Shayam Ji    24
# Mridul       21
# Prem         22
# dtype: int64
# 20

# %%
s=pd.Series([100,1,2,3,4])
print(s)
changed_s=s.drop(0)
print(changed_s)
# Out:
# 0    100
# 1      1
# 2      2
# 3      3
# 4      4
# dtype: int64
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64
